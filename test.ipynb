# %%
! python cifar_main.py --depth 20
# Out:
# ==> Preparing dataset cifar10
# Files already downloaded and verified
# ==> creating model 'resnet'
#     Total params: 0.27M
#
# Epoch: [1 | 200] LR: 0.100000
# Train Loss/Acc: 1.62/39.19
# Test Loss/Acc: 1.26/53.61
#
# Epoch: [2 | 200] LR: 0.100000
# Train Loss/Acc: 1.12/59.32
# Test Loss/Acc: 1.34/56.37
#
# Epoch: [3 | 200] LR: 0.100000
# Train Loss/Acc: 0.90/67.83
# Test Loss/Acc: 0.89/68.04
#
# Epoch: [4 | 200] LR: 0.100000
# Train Loss/Acc: 0.78/72.90
# Test Loss/Acc: 0.88/70.08
#
# Epoch: [5 | 200] LR: 0.100000
# Train Loss/Acc: 0.70/75.68
# Test Loss/Acc: 1.15/64.82
#
# Epoch: [6 | 200] LR: 0.100000
# Train Loss/Acc: 0.66/77.31
# Test Loss/Acc: 1.24/63.48
#
# Epoch: [7 | 200] LR: 0.100000
# Train Loss/Acc: 0.64/77.91
# Test Loss/Acc: 0.75/75.37
#
# Epoch: [8 | 200] LR: 0.100000
# Train Loss/Acc: 0.61/79.06
# Test Loss/Acc: 0.77/74.13
#
# Epoch: [9 | 200] LR: 0.100000
# Train Loss/Acc: 0.59/79.80
# Test Loss/Acc: 0.85/73.16
#
# Epoch: [10 | 200] LR: 0.100000
# ...
